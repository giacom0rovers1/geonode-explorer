# %%
import geonodexplorer as geo

# %% [markdown]
# # GeoNode explorer for **SIP**
# Explore metadata of online resources through the GeoNode APIs.
#
# Load the content:

# %%
sip = geo.content(name     = "SCORE EU Platform", 
                  nickname = "SIP", 
                  url      = "https://platform.score-eu-project.eu/api/v2/resources")
# Out:
# https://platform.score-eu-project.eu/api/v2/resources?filter{resource_type}=dataset
# Page 1  [page size: 10, total: 68]
# Page 2  [page size: 10, total: 68]
# Page 3  [page size: 10, total: 68]
# Page 4  [page size: 10, total: 68]
# Page 5  [page size: 10, total: 68]
# Page 6  [page size: 10, total: 68]
# Page 7  [page size: 10, total: 68]
# https://platform.score-eu-project.eu/api/v2/resources?filter{resource_type}=map
# Page 1  [page size: 10, total: 4]
# https://platform.score-eu-project.eu/api/v2/resources?filter{resource_type}=document
# Page 1  [page size: 10, total: 56]
# Page 2  [page size: 10, total: 56]
# Page 3  [page size: 10, total: 56]
# Page 4  [page size: 10, total: 56]
# Page 5  [page size: 10, total: 56]
# Page 6  [page size: 10, total: 56]
# https://platform.score-eu-project.eu/api/v2/resources?filter{resource_type}=geostory
# Page 1  [page size: 10, total: 10]
# https://platform.score-eu-project.eu/api/v2/resources?filter{resource_type}=dashboard
# Page 1  [page size: 10, total: 3]
# Done.

# %% [markdown]
# Plot the DataFrame and export it to CSV:

# %%
sip.print_()
sip.save_CSV()
# Out:
#        PK                                  UUID  \
# 0    5215  a3376471-9946-4c87-9ed3-f73cd22b48d6
# 1    5214  c7f01225-bb50-4480-a532-d607f61a0eaf
# 2    5213  7e3dcf53-5cc4-495f-87c4-41d0d7084281
# 3    5212  e1317ff6-c843-4300-a02f-28a7add67a20
# 4    5211  575c2436-91a0-4406-982d-8335efb64505
# ..    ...                                   ...
# 136    54  3a617c87-09da-46c2-bd4b-767660b91206
# 137    44  825e5259-b801-43e8-93e5-7661f439a8b8
# 138  5285  8eaa0e77-fbc4-48dc-b359-97b83b34afcd
# 139  5223  0b0ef490-f17d-45d9-9628-6f1efe4d72ad
# 140    46  18be3266-5b7d-4a2f-9387-522e6bf3adb4
#
#                                     Title                       Author  \
# 0                                   river      samsun (Neslihan BEDEN)
# 1                               banklines      samsun (Neslihan BEDEN)
# 2                                 bridges      samsun (Neslihan BEDEN)
# 3                                 dtm_2x2  ent (Luís Campos Rodrigues)
# 4                          batimetria_ihm  ent (Luís Campos Rodrigues)
# ..                                    ...                          ...
# 136  Overview of CCLL of Piran (Slovenia)     piran (Cecil Meulenberg)
# 137     Overview of CCLL of Massa (Italy)                    admin ( )
# 138                           EBA Hazards     dublin (Francesco Pilla)
# 139                         EBA Categorys     dublin (Francesco Pilla)
# 140     Municipality of Massa - Dashboard                    admin ( )
#
#           Type        License                    Created  \
# 0      dataset  not_specified 2023-06-07 20:42:10.627926
# 1      dataset  not_specified 2023-06-07 20:42:09.812565
# 2      dataset  not_specified 2023-06-07 20:42:09.450330
# 3      dataset  not_specified 2023-05-29 09:38:28.279478
# 4      dataset  not_specified 2023-05-26 10:06:00.165516
# ..         ...            ...                        ...
# 136   geostory  not_specified 2022-07-27 12:30:25.756591
# 137   geostory  not_specified 2022-06-28 11:39:49.349495
# 138  dashboard  not_specified 2023-06-21 15:12:07.575716
# 139  dashboard  not_specified 2023-06-14 15:02:07.182193
# 140  dashboard  not_specified 2022-06-28 12:54:43.626006
#
#                   Last updated  \
# 0   2023-06-07 20:42:19.721533
# 1   2023-06-07 20:42:18.324294
# 2   2023-06-07 20:42:16.097866
# 3   2023-05-29 09:38:33.046946
# 4   2023-05-26 10:06:05.754675
# ..                         ...
# 136 2023-04-06 14:30:57.686984
# 137 2023-07-04 12:30:36.376845
# 138 2023-06-30 09:07:24.594235
# 139 2023-06-30 09:07:40.757802
# 140 2023-03-21 17:23:12.763089
#
#                                               Abstract  \
# 0
# 1
# 2
# 3
# 4
# ..                                                 ...
# 136  <p><span class="fontstyle0">PIRAN </span><span...
# 137                        <p>No abstract provided</p>
# 138
# 139
# 140                        <p>No abstract provided</p>
#
#                                              Alt-name   DOI
# 0                                       geonode:river  None
# 1                                   geonode:banklines  None
# 2                                     geonode:bridges  None
# 3    geonode:dtm_2x2_3ec3eef7fac1be8fa42af1992a08786a  None
# 4                              geonode:batimetria_ihm  None
# ..                                                ...   ...
# 136                                              None  None
# 137                                              None  None
# 138                                              None  None
# 139                                              None  None
# 140                                              None  None
#
# [141 rows x 11 columns]

# %% [markdown]
# Plot some exploratory graphs:

# %%
sip.plot_AuthorsHist()

# %%
sip.plot_TypesPie()

# %%
sip.plot_AggregTS()

# %%
sip.plot_Contributions()
